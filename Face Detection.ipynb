# %% [markdown]
# ## Face Detection with Python using OpenCV

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %%
import cv2
import sys

image= cv2.imread('download1.jpg')
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image,0)

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30)
)

print("Found {0} Faces!".format(len(faces)))

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 255), 1)

status = cv2.imwrite('download1.jpg', image)
print("Image download1.jpg written to filesystem: ", status)
plt.imshow(image)
# Out:
# Found 2 Faces!
# Image download1.jpg written to filesystem:  True

# %%
# detector= cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')


# image= cv2.imread('kylie.jpg')
# image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# gray = cv2.cvtColor(image,0)
# faces = detector.detectMultiScale(gray,1.3, 5)
# for (x,y,w,h) in faces:
#     cv2.rectangle(image,(x,y),(x+w,y+h),(255,255,0),2)

# plt.imshow(image)

# %% [markdown]
# ## Face Detection using Python and OpenCV with webcam

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') 
    
cap = cv2.VideoCapture(0) 
   
while 1:  
    
    ret, img = cap.read()  
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(20,20)
    ) 
    
  
    for (x,y,w,h) in faces:   
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)  
        roi_gray = gray[y:y+h, x:x+w] 
        roi_color = img[y:y+h, x:x+w]  
    cv2.imshow('img',img)  
    k = cv2.waitKey(30) & 0xff
    if k == 27: 
        break
        
    print("Found {0} Faces!".format(len(faces)))
        
cap.release() 
cv2.destroyAllWindows()
# Out:
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
